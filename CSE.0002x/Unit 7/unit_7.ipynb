# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
x = np.linspace(0.0, 1.0, 31)
f1 = x
f2 = x**2

# plotting
fig = plt.figure()
plt.plot(x, f1, color='r', marker='o', linestyle='-', label='f(x)=x')
plt.plot(x, f2, color='b', marker='x', linestyle='-.', label='f(x)=x^2')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title('Our first plot!')

# draw the grid on the figure
plt.grid()

# create the legend
plt.legend()

# save the figure to a file you can then send to your friends
fig.savefig("pyplotexampleplot.png")

# display the figure
plt.show()
print("x =", x)
# Out:
# x = [0.         0.03333333 0.06666667 0.1        0.13333333 0.16666667
#  0.2        0.23333333 0.26666667 0.3        0.33333333 0.36666667
#  0.4        0.43333333 0.46666667 0.5        0.53333333 0.56666667
#  0.6        0.63333333 0.66666667 0.7        0.73333333 0.76666667
#  0.8        0.83333333 0.86666667 0.9        0.93333333 0.96666667
#  1.        ]

# %%
fig2 = plt.figure()
plt.plot(x, f1, color='r', marker='o', linestyle='-', label='f(x)=x')
plt.show()

fig3 = plt.figure()
plt.plot(x, f2, color='b', marker='x', linestyle='-.', label='f(x)=x^2')
plt.show()

# Now there are 2 separate plots because we used 2 separate plt.figure() calls.

# %%
# The object-oriented approach:

import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
x = np.linspace(0.0, 1.0, 31)
f1 = x
f2 = x**2

# plotting
fig, ax = plt.subplots()
ax.plot(x, f1, color='r', marker='o', linestyle='-', label='f(x)=x')
ax.plot(x, f2, color='b', marker='x', linestyle='-.', label='f(x)=x^2')
ax.set_xlabel("x label")
ax.set_ylabel("y label")
ax.set_title("Our first plot!")

# draw the grid on the figure
ax.grid()

# create the legend
ax.legend()

# save the figure to a file you can then send to your friends
fig.savefig("ObjectOrientedexampleplot.png")

# display the figure
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

N_points = 100000
n_bins = 20

# Generate a normal distribution centered at x=0
rng = np.random.default_rng()
x = rng.normal(0., 1., N_points)

# plt.subplot("number of rows", "number of columns", "subplot index")
plt.subplot(1,2,1)

# We can set the number of bins with the `bins` kwarg
plt.hist(x, bins=n_bins)
plt.ylabel("Count")
plt.xlabel("Data")

plt.subplot(1,2,2)
plt.hist(x, density=True, bins=n_bins)
plt.ylabel("Density")
plt.xlabel("Data")

print("x =", x)
# Out:
# x = [-1.26621324  0.74081417 -0.79626988 ... -0.17629259 -0.66582348
#  -1.50046592]

# %%
# Object oriented approach:

import matplotlib.pyplot as plt
import numpy as np

N_points = 100000
n_bins = 20

# Generate a normal distribution centered at x=0
rng = np.random.default_rng()
x = rng.normal(0., 1., N_points)

fig, axs = plt.subplots(1, 2, tight_layout=True)

# We can set the number of bins with the `bins` kwarg
axs[0].hist(x, bins=n_bins)
axs[0].set_ylabel("Count")
axs[0].set_xlabel("Data")

axs[1].hist(x, density=True, bins=n_bins)
axs[1].set_ylabel("Density")
axs[1].set_xlabel("Data")
# Out:
# Text(0.5, 0, 'Data')
